# %%
#https://pypi.org/project/bing-image-downloader/

# !pip install bing-image-downloader
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
# !mkdir images

# %%
 from bing_image_downloader import downloader
 downloader.download("gondola de supermercado", limit=500, output_dir='images')
# Out:
# [%] Downloading Images to /content/images/gondola de supermercado
#
#
# [!!]Indexing page: 1
#
# [%] Indexed 150 Images on Page 1.
#
# ...
#
# [%] Downloading Image #1 from https://media.minutouno.com/p/318e46e1d2dbf3db9ac4c774d15cdd7a/adjuntos/150/imagenes/023/609/0023609732/supermercados-rosariojpg.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #2 from https://i.pinimg.com/originals/65/b6/27/65b6274e2faa75d27a89085ff8bf181b.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #3 from http://www.blangondolas.com.br/site/wp-content/uploads/2017/09/gondolas-ITALO-SLO.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #4 from https://www.solucoesindustriais.com.br/images/produtos/imagens_10335/p_gondolas-para-supermercado_10335_41457_1.jpg
# [!] Issue getting: https://www.solucoesindustriais.com.br/images/produtos/imagens_10335/p_gondolas-para-supermercado_10335_41457_1.jpg
# ...
